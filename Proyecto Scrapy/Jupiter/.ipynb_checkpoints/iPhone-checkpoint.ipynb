# %% [markdown]
# # Análisis iPhone

# %% [markdown]
# El objetivo del presente proyecto es realizar una comparativa de las diferentes versiones de iPhone, y cómo ha variado la percepción del público a través de los años

# %% [markdown]
# # Web Scraping

# %% [markdown]
# Esta información fue obtenida a traves de scraping a la página web: http://socialcompare.com/en/comparison/apple-iphone-product-line-comparison
#
# Mediante un spider de Scrapy se seleccionó las datos más relevantes y se almacenaron en un archivo csv. Posteriormente este archivo fue importado a un dataframe de Pandas.

# %%
import pandas as pd
df_iphone = pandas.read_csv('../scrapy/iphone.csv')
df_iphone = df_iphone.sort_values('fecha')
df_iphone = df_iphone.reset_index(drop=True)
df_iphone
# Out:
#             modelo  pulgadas_pantalla  resolucion_camara    ram  bateria  \
# 0       iPhone 3GS                3.5                  3  0.256     1219
# 1         iPhone 4                3.5                  5  0.512     1420
# 2        iPhone 4S                3.5                  8  1.000     1432
# 3         iPhone 5                4.0                  8  1.000     1440
# 4        iPhone 5C                4.0                  8  1.000     1507
# 5        iPhone 5S                4.0                  8  1.000     1570
# 6         iPhone 6                4.7                  8  1.000     1810
# 7    iPhone 6 Plus                5.5                  8  1.000     2915
# 8        iPhone 6s                4.7                 12  2.000     1715
# 9   iPhone 6s Plus                5.5                 12  2.000     2750
# 10       iPhone SE                4.0                 12  2.000     1624
# 11   iPhone 7 Plus                5.5                 12  3.000     2900
# 12        iPhone 7                4.7                 12  2.000     1960
# 13        iPhone 8                4.7                 12  2.000     1821
# 14   iPhone 8 Plus                5.5                 12  3.000     2675
# 15   iPhone X (10)                5.8                 12  3.000     2716
# 16   iPhone XS Max                6.5                 12  4.000     3174
# 17       iPhone XS                5.8                 12  4.000     2658
# 18       iPhone XR                6.1                 12  3.000     2942
#
#     almacenamiento       fecha
# 0               32  2009-06-19
# 1               32  2010-06-24
# 2               64  2011-10-14
# 3               64  2012-09-21
# 4               32  2013-09-10
# 5               64  2013-09-10
# 6              128  2014-09-09
# 7              128  2014-09-09
# 8              128  2015-09-12
# 9              128  2015-09-12
# 10              64  2016-03-21
# 11             256  2016-09-16
# 12              32  2016-09-16
# 13             256  2017-09-15
# 14             256  2017-09-15
# 15             256  2017-10-27
# 16             512  2018-09-28
# 17             512  2018-09-28
# 18             256  2018-10-26

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
pv_primeros= df_iphone.filter(items = ["modelo", "ram"]).sort_values('ram', ascending=False).head(10)

# %%
plt.figure(figsize=(16,8))
# plot chart
ax1 = plt.subplot(121, aspect='equal')

pv_primeros.plot(kind='pie', y = 'ram', ax=ax1, autopct='%1.1f%%', 
 startangle=100, shadow=False, labels=pv_primeros['modelo'], fontsize=10)
plt.axis('equal')

# View the plot
plt.show()

# %% [markdown]
# # Precios

# %% [markdown]
# Adicionalmente se obtuvo el precio de venta inicial de cada iPhone, ajustado a la inflación. A partir de un csv: https://www.reddit.com/r/dataisbeautiful/comments/9vak24/the_cost_of_each_iphone_at_launch_adjusted_for/

# %%
df_precio = pandas.read_csv('precio_iphone.csv')
df_precio
# Out:
#               unit  year  price
# 0       iPhone 3GS  2009    700
# 1         iPhone 4  2010    692
# 2        iPhone 4S  2011    722
# 3         iPhone 5  2012    708
# 4        iPhone 5C  2013    584
# 5        iPhone 5S  2013    700
# 6         iPhone 6  2014    688
# 7    iPhone 6 Plus  2014    784
# 8        iPhone 6S  2015    689
# 9   iPhone 6S Plus  2015    783
# 10       iPhone SE  2016    395
# 11   iPhone 7 Plus  2016    804
# 12        iPhone 7  2016    679
# 13        iPhone 8  2017    715
# 14   iPhone 8 Plus  2017    809
# 15   iPhone X (10)  2017   1022
# 16   iPhone XS Max  2018   1099
# 17       iPhone XS  2018    999
# 18       iPhone XR  2018    749

# %%
pvp = df_precio.filter(items = ["unit","price"]).sort_values('price', ascending=False)
pvp.plot(kind="bar",title="Precios")

# %%
df_iphone['precio'] = df_precio['price']
df_iphone
# Out:
#             modelo  pulgadas_pantalla  resolucion_camara    ram  bateria  \
# 0       iPhone 3GS                3.5                  3  0.256     1219
# 1         iPhone 4                3.5                  5  0.512     1420
# 2        iPhone 4S                3.5                  8  1.000     1432
# 3         iPhone 5                4.0                  8  1.000     1440
# 4        iPhone 5C                4.0                  8  1.000     1507
# 5        iPhone 5S                4.0                  8  1.000     1570
# 6         iPhone 6                4.7                  8  1.000     1810
# 7    iPhone 6 Plus                5.5                  8  1.000     2915
# 8        iPhone 6s                4.7                 12  2.000     1715
# 9   iPhone 6s Plus                5.5                 12  2.000     2750
# 10       iPhone SE                4.0                 12  2.000     1624
# 11   iPhone 7 Plus                5.5                 12  3.000     2900
# 12        iPhone 7                4.7                 12  2.000     1960
# 13        iPhone 8                4.7                 12  2.000     1821
# 14   iPhone 8 Plus                5.5                 12  3.000     2675
# 15   iPhone X (10)                5.8                 12  3.000     2716
# 16   iPhone XS Max                6.5                 12  4.000     3174
# 17       iPhone XS                5.8                 12  4.000     2658
# 18       iPhone XR                6.1                 12  3.000     2942
#
#     almacenamiento       fecha  precio
# 0               32  2009-06-19     700
# 1               32  2010-06-24     692
# 2               64  2011-10-14     722
# 3               64  2012-09-21     708
# 4               32  2013-09-10     584
# 5               64  2013-09-10     700
# 6              128  2014-09-09     688
# 7              128  2014-09-09     784
# 8              128  2015-09-12     689
# 9              128  2015-09-12     783
# 10              64  2016-03-21     395
# 11             256  2016-09-16     804
# 12              32  2016-09-16     679
# 13             256  2017-09-15     715
# 14             256  2017-09-15     809
# 15             256  2017-10-27    1022
# 16             512  2018-09-28    1099
# 17             512  2018-09-28     999
# 18             256  2018-10-26     749

# %%
plot = df_iphone.plot(x='fecha',y='precio')
plot.set_ylim(0, 1200)
# Out:
# (0, 1200)

# %% [markdown]
# Medante scrapy obtenemos el conteo de cuentas de la pagina principal en un archivo json.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3

# %%
datos = pd.read_json('../Scrapy/data/datos.json')

# %%
datos_parcial = datos[datos['name'] != 'Total Accounts']

# %%
labels = datos_parcial['name']
sizes = datos_parcial['value']
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.axis('equal') 
plt.legend(loc="lower right", bbox_to_anchor=(1.5, 0))
plt.title('Distribución por plataforma')
plt.show()

# %% [markdown]
# # Resultado
# Se puede dividir a las platformas en en tres grupos, el primero que contiene la plataforma de YouTube que es la mas usada para crear contenidos, el segundo que contiene sitios similares en uso com lo son Twitch, Twitter e Instagram y el tercer grupo con poco conteo de cuentas como Facebook, Dailymotion y Stremers

# %%
# Youtube
youtubetop100 = pd.read_json('../Scrapy/data/youtube_top100.json')
youtubetop100.head()
# Out:
#   grade  rank      subs  uploads  \
# 0   A++     1  84165304    13103
# 1   A++     2  35856476      398
# 2   A++     3   1230286     2651
# 3   A++     4  41275374    28774
# 4   A++     5   1492793      121
#
#                                               uri                    username  \
# 0  https://socialblade.com/youtube/c/tseriesmusic                    T-Series
# 1     https://socialblade.com/youtube/c/cocomelon  Cocomelon - Nursery Rhymes
# 2    https://socialblade.com/youtube/c/ hkcinema                     HKCinema
# 3     https://socialblade.com/youtube/c/set-india                   SET India
# 4     https://socialblade.com/youtube/c/posteries                   Posteries
#
#          views
# 0  61057139207
# 1  19388551809
# 2    718966136
# 3  28573512222
# 4    675657643

# %% [markdown]
# # Twitch

# %%
twitchtop100 = pd.read_json('../Scrapy/data/twitch-top100.json')
twitchtop100.head()
# Out:
#   grade  rank      subs                                           uri  \
# 0   A++     1  13295895     https://socialblade.com/twitch/user/ninja
# 1   A++     2   5304272    https://socialblade.com/twitch/user/shroud
# 2   A++     3   4908770  https://socialblade.com/twitch/user/meclipse
# 3   A++     4   4845251  https://socialblade.com/twitch/user/tsm_myth
# 4   A++     5   4834461      https://socialblade.com/twitch/user/tfue
#
#    username      views
# 0     ninja  410947464
# 1    shroud  268289375
# 2  meclipse  242068259
# 3  tsm_myth   70366867
# 4      tfue   83990775

# %% [markdown]
# # Twitter

# %%
twittertop100 = pd.read_json('../Scrapy/data/twitter-top100.json')
twittertop100.head()
# Out:
#    follow grade  rank       subs  uploads  \
# 0     215   A++     1  106882074     9364
# 1  298906   A++     2  104997556    30501
# 2  615997   A++     3  104516135    15576
# 3    1090   A++     4   89373655    10236
# 4       0   A++     5   83335148      103
#
#                                                  uri       username
# 0     https://socialblade.com/twitter/user/katyperry      katyperry
# 1  https://socialblade.com/twitter/user/justinbieber   justinbieber
# 2   https://socialblade.com/twitter/user/BarackObama    BarackObama
# 3       https://socialblade.com/twitter/user/rihanna        rihanna
# 4  https://socialblade.com/twitter/user/taylorswi...  taylorswift13

# %% [markdown]
# # Instagram

# %%
instagramtop100 = pd.read_json('../Scrapy/data/instagram-top100.json')
instagramtop100.head()
# Out:
#    follow grade  rank       subs  uploads  \
# 0     342   A++     1  131145432     4070
# 1     940   A++     2  110952719     4384
# 2     222   A++     3  108650319      413
# 3     135   A++     4   99489262    19414
# 4    1089   A++     5   86060066     2654
#
#                                                uri             username
# 0   https://socialblade.com/instagram/user/therock              therock
# 1  https://socialblade.com/instagram/user/neymarjr              EneJota
# 2  https://socialblade.com/instagram/user/leomessi            Leo Messi
# 3    https://socialblade.com/instagram/user/natgeo  National Geographic
# 4       https://socialblade.com/instagram/user/jlo       Jennifer Lopez

# %% [markdown]
# Se agrega la columna "origen" a cada Dataframe:

# %%
youtubetop100['origen'] = 'YouTube'
twitchtop100['origen'] = 'Twitch'
twittertop100['origen'] = 'Twitter'
instagramtop100['origen'] = 'Instagram'

# %% [markdown]
# Obtenemos una tabla general con todos los datos:

# %%
db = pd.concat([youtubetop100, twitchtop100, twittertop100, instagramtop100], sort=False)
db.head()
# Out:
#   grade  rank      subs  uploads  \
# 0   A++     1  84165304  13103.0
# 1   A++     2  35856476    398.0
# 2   A++     3   1230286   2651.0
# 3   A++     4  41275374  28774.0
# 4   A++     5   1492793    121.0
#
#                                               uri                    username  \
# 0  https://socialblade.com/youtube/c/tseriesmusic                    T-Series
# 1     https://socialblade.com/youtube/c/cocomelon  Cocomelon - Nursery Rhymes
# 2    https://socialblade.com/youtube/c/ hkcinema                     HKCinema
# 3     https://socialblade.com/youtube/c/set-india                   SET India
# 4     https://socialblade.com/youtube/c/posteries                   Posteries
#
#           views   origen  follow
# 0  6.105714e+10  YouTube     NaN
# 1  1.938855e+10  YouTube     NaN
# 2  7.189661e+08  YouTube     NaN
# 3  2.857351e+10  YouTube     NaN
# 4  6.756576e+08  YouTube     NaN

# %% [markdown]
# # YouTube: Identificar los tipos de canales mas populares

# %%
with sqlite3.connect('socialblade.db') as conexion:
    cur = conexion.cursor()
    cur.execute("DROP TABLE IF EXISTS accounts")
    db.to_sql('accounts', conexion, if_exists='append')

# %%
labels = counts_youtube_categories.keys()
sizes = counts_youtube_categories.values
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.legend(loc="lower right", bbox_to_anchor=(1.5, 0))
plt.title('Categorias de canales de YouTube')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-107-81d91e760cf0> in <module>
# ----> 1 labels = counts_youtube_categories.keys()
#       2 sizes = counts_youtube_categories.values
#       3 fig1, ax1 = plt.subplots()
#       4 ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
#       5 ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
#
# NameError: name 'counts_youtube_categories' is not defined
